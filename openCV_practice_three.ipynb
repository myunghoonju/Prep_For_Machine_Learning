# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-14ac87b6-1bd1-496b-986f-4be06bbf8655" name="files[]" multiple disabled />
#      <output id="result-14ac87b6-1bd1-496b-986f-4be06bbf8655">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving waldo.png to waldo.png

# %%
winter_image = cv2.imread('./pic.jpg')

# %%
pixcel = winter_image[200,250]

# %%
print(pixcel) #RGB representation
# Out:
# [65 66 64]

# %%
winter_image[200,250] = (255,0,0) #change pixcel colour

# %%
winter_image[200:250,200:350] = (0,250,0) #change colour of area

# %%
plt.imshow(winter_image)

# %%
winter_image[200:270,200:300] = (255,0,0)

# %%
plt.imshow(winter_image)

# %%
#geo function
#line(), rectangle(), circle(), ellipse(), polygon(), putText() etc..,

# %%
#find waldo
img_rgb = cv2.imread('find_waldo.jpg')

# %%
plt.imshow(img_rgb)

# %%
type(img_rgb)
# Out:
# numpy.ndarray

# %%
img_gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)

# %%
template = cv2.imread('waldo.png',0) #gray

# %%
w,h = template.shape[::-1]

# %%
res  = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)

# %%
threshold = 0.6

# %%
loc = np.where(res >= threshold)

# %%
for pt in zip(*loc[::-1]):
  cv2.rectangle(img_rgb,pt,(pt[0]+w,pt[1]+h),(0,255,0),2)

# %%
cv2.imwrite('found.png',img_rgb)
# Out:
# True

# %%
aaa = cv2.imread('found.png')

# %%
plt.imshow(aaa) #there he is!!
