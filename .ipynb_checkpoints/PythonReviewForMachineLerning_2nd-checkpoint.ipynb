# %% [markdown]
# ### matplotlib

# %%
# %matplotlib notebook 
from matplotlib import pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('numbers')
plt.show()

#for activate plot in jupyter notebook
#add %matplotlib notebook
#https://medium.com/@1522933668924/using-matplotlib-in-jupyter-notebooks-comparing-methods-and-some-tips-python-c38e85b40ba1
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# 'shape_of_point' e.g. 'o' == circle(default colour is blue), 'x', '*','--', etc
plt.plot([1,2,3,4],[1,4,9,16],'o')
plt.axis([0,20,0,20]) # range of x and y axis from 0 to 20
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### tf.Session(): build & launch graphs
